# %%
import pandas as pd
xls=pd.ExcelFile('C:/Users/HP/Downloads/Mod 2 Code & Data Files/yelp.xlsx')
df=xls.parse('yelp_data')

# %%
df.head()
# Out:
#                            name   category_0       category_1  take_out  \
# 0  China Sea Chinese Restaurant  Restaurants          Chinese      True
# 1          Discount Tire Center        Tires       Automotive     False
# 2                  Frankfurters  Restaurants         Hot Dogs      True
# 3             Fred Dietz Floral     Shopping  Flowers & Gifts     False
# 4                 Kuhn's Market         Food          Grocery     False
#
#    review_count  stars  city_id  state_id
# 0            11    2.5        1         1
# 1            24    4.5        1         1
# 2             3    4.5        1         1
# 3             6    4.0        1         1
# 4             8    3.5        1         1

# %%
df_cities=xls.parse('cities')
df_cities.head()
# Out:
#    id           city
# 0   1       Bellevue
# 1   2       Braddock
# 2   3       Carnegie
# 3   4      Homestead
# 4   5  Mc Kees Rocks

# %%
df = pd.merge(left=df, right=df_cities, how='inner', left_on='city_id', right_on='id')

# %%
df.head()
# Out:
#                            name   category_0       category_1  take_out  \
# 0  China Sea Chinese Restaurant  Restaurants          Chinese      True
# 1          Discount Tire Center        Tires       Automotive     False
# 2                  Frankfurters  Restaurants         Hot Dogs      True
# 3             Fred Dietz Floral     Shopping  Flowers & Gifts     False
# 4                 Kuhn's Market         Food          Grocery     False
#
#    review_count  stars  city_id  state_id  id      city
# 0            11    2.5        1         1   1  Bellevue
# 1            24    4.5        1         1   1  Bellevue
# 2             3    4.5        1         1   1  Bellevue
# 3             6    4.0        1         1   1  Bellevue
# 4             8    3.5        1         1   1  Bellevue

# %%
df_states=xls.parse('states')

# %%
df_states.head()
# Out:
#    id state
# 0   1    PA
# 1   2    NV

# %%
df = pd.merge(left=df, right=df_states, how='inner', left_on='state_id', right_on='id')

# %%
df.shape
# Out:
# (600, 12)

# %%
df.head()
# Out:
#                            name   category_0       category_1  take_out  \
# 0  China Sea Chinese Restaurant  Restaurants          Chinese      True
# 1          Discount Tire Center        Tires       Automotive     False
# 2                  Frankfurters  Restaurants         Hot Dogs      True
# 3             Fred Dietz Floral     Shopping  Flowers & Gifts     False
# 4                 Kuhn's Market         Food          Grocery     False
#
#    review_count  stars  city_id  state_id  id_x      city  id_y state
# 0            11    2.5        1         1     1  Bellevue     1    PA
# 1            24    4.5        1         1     1  Bellevue     1    PA
# 2             3    4.5        1         1     1  Bellevue     1    PA
# 3             6    4.0        1         1     1  Bellevue     1    PA
# 4             8    3.5        1         1     1  Bellevue     1    PA

# %%
atts=['name', 'city', 'state']
df[atts].head(100)
# Out:
#                                               name        city state
# 0                     China Sea Chinese Restaurant    Bellevue    PA
# 1                             Discount Tire Center    Bellevue    PA
# 2                                     Frankfurters    Bellevue    PA
# 3                                Fred Dietz Floral    Bellevue    PA
# 4                                    Kuhn's Market    Bellevue    PA
# ..                                             ...         ...   ...
# 95                             Aamco Transmissions  Pittsburgh    PA
# 96  Animal Rescue League Shelter & Wildlife Center  Pittsburgh    PA
# 97                          Aracri's Greentree Inn  Pittsburgh    PA
# 98                           Atch-Mont Real Estate  Pittsburgh    PA
# 99                              Atria's Restaurant  Pittsburgh    PA
#
# [100 rows x 3 columns]

# %%
del df['id_x']
del df['id_y']

# %%
df.head()
# Out:
#                            name   category_0       category_1  take_out  \
# 0  China Sea Chinese Restaurant  Restaurants          Chinese      True
# 1          Discount Tire Center        Tires       Automotive     False
# 2                  Frankfurters  Restaurants         Hot Dogs      True
# 3             Fred Dietz Floral     Shopping  Flowers & Gifts     False
# 4                 Kuhn's Market         Food          Grocery     False
#
#    review_count  stars  city_id  state_id      city state
# 0            11    2.5        1         1  Bellevue    PA
# 1            24    4.5        1         1  Bellevue    PA
# 2             3    4.5        1         1  Bellevue    PA
# 3             6    4.0        1         1  Bellevue    PA
# 4             8    3.5        1         1  Bellevue    PA

# %%
df[100:150]
# Out:
#                                               name  \
# 100                                 Au Bon Pain Co
# 101               Bado's Pizza Grill and Ale House
# 102                           Bastone Auto Service
# 103                      Bellisario's Pizza Palace
# 104         Benedum Center for the Performing Arts
# 105                                   Beto's Pizza
# 106                              Better-Maid Donut
# 107                                    Big Burrito
# 108                       Billy's Troy Hill Bistro
# 109                      Boehmer Heating & Cooling
# 110                                     BreadWorks
# 111                            Broadway Auto Parts
# 112                                Brown Bag Delis
# 113                              Bruegger's Bagels
# 114                                  Buffalo Blues
# 115                               Buon Giorno Cafe
# 116                                  Cain's Saloon
# 117                  Calabria's Italian Restaurant
# 118                               Candalina Brides
# 119                                   Cappy's Cafe
# 120                  Capristo Salon & Wellness Spa
# 121                              Cardamone's Salon
# 122  Carnegie Library of Pittsburgh - East Liberty
# 123                          Cat Clinic & Hospital
# 124                Children's Museum of Pittsburgh
# 125         Chinese Acupuncture & Herbs Center LLC
# 126                  Christos Mediterranean Grille
# 127             Chubby's Pizza & Hoagies Northside
# 128                      Cindy Esser's Floral Shop
# 129                              Cool Beans Coffee
# 130                  Courtyard Pittsburgh Downtown
# 131                             Crepes Parisiennes
# 132                  Crouse Wayne Beer Distributor
# 133                                   CVS Pharmacy
# 134                                    Dairy Queen
# 135                        Dan Cercone Hairstyling
# 136         Decio's Custom Tailoring & Formal Wear
# 137                    Dependable Brakes & Exhaust
# 138                                    Doc's Place
# 139                                    Don's Diner
# 140                         Dormont Public Library
# 141                                Dunning's Grill
# 142                                    e.b. Pepper
# 143                      East End Community Thrift
# 144                          Eat'n Park Restaurant
# 145                              Econowash Laundry
# 146                             Eddie's Pizza Haus
# 147                          Elite Coach Limousine
# 148                                     Elks B P O
# 149                       Emmert Dental Associates
#
#                        category_0                       category_1  take_out  \
# 100                          Food                         Bakeries     False
# 101                       Italian                             Bars      True
# 102                   Auto Repair                       Automotive     False
# 103                       Italian                            Pizza      True
# 104                Opera & Ballet             Arts & Entertainment     False
# 105                   Restaurants                            Pizza      True
# 106                          Food                         Bakeries      True
# 107     Event Planning & Services                         Caterers     False
# 108                   Restaurants                            Cafes      True
# 109                 Home Services  Heating & Air Conditioning/HVAC     False
# 110                          Food                         Bakeries      True
# 111                   Auto Repair                       Automotive     False
# 112                   Restaurants                            Delis      True
# 113                          Food                       Sandwiches      True
# 114                   Restaurants                             Bars      True
# 115                   Restaurants                          Italian      True
# 116                   Restaurants                   American (New)      True
# 117                   Restaurants                            Pizza     False
# 118                      Shopping                           Bridal     False
# 119                          Bars           American (Traditional)      True
# 120                   Hair Salons                    Beauty & Spas     False
# 121                   Hair Salons                    Beauty & Spas     False
# 122  Public Services & Government                        Libraries     False
# 123                 Veterinarians                             Pets     False
# 124                       Museums             Arts & Entertainment     False
# 125                   Acupuncture     Traditional Chinese Medicine     False
# 126                         Greek                    Mediterranean      True
# 127                   Restaurants                            Pizza      True
# 128                      Shopping                  Flowers & Gifts     False
# 129                          Food                     Coffee & Tea     False
# 130               Hotels & Travel        Event Planning & Services     False
# 131            Breakfast & Brunch                        Creperies      True
# 132                          Food             Beer, Wine & Spirits     False
# 133                      Shopping                       Drugstores     False
# 134                          Food        Ice Cream & Frozen Yogurt      True
# 135                       Barbers                    Beauty & Spas     False
# 136                Local Services             Sewing & Alterations     False
# 137                   Auto Repair                       Automotive     False
# 138                          Bars                            Pizza      True
# 139                   Restaurants                           Diners      True
# 140  Public Services & Government                        Libraries     False
# 141                   Restaurants           American (Traditional)      True
# 142              Women's Clothing                          Fashion     False
# 143   Used, Vintage & Consignment                          Fashion     False
# 144                     Fast Food           American (Traditional)      True
# 145                Local Services           Dry Cleaning & Laundry     False
# 146                       Italian                            Pizza      True
# 147               Hotels & Travel                 Airport Shuttles     False
# 148          Arts & Entertainment                     Social Clubs     False
# 149              Health & Medical                    Periodontists     False
#
#      review_count  stars  city_id  state_id        city state
# 100             7    3.0        8         1  Pittsburgh    PA
# 101            93    3.5        8         1  Pittsburgh    PA
# 102            20    4.0        8         1  Pittsburgh    PA
# 103            21    3.5        8         1  Pittsburgh    PA
# 104            56    4.5        8         1  Pittsburgh    PA
# 105           145    4.0        8         1  Pittsburgh    PA
# 106            32    4.5        8         1  Pittsburgh    PA
# 107             3    5.0        8         1  Pittsburgh    PA
# 108             5    3.0        8         1  Pittsburgh    PA
# 109            13    4.0        8         1  Pittsburgh    PA
# 110            17    4.5        8         1  Pittsburgh    PA
# 111             4    5.0        8         1  Pittsburgh    PA
# 112             5    2.0        8         1  Pittsburgh    PA
# 113            23    3.0        8         1  Pittsburgh    PA
# 114            62    3.0        8         1  Pittsburgh    PA
# 115             6    3.5        8         1  Pittsburgh    PA
# 116           106    3.5        8         1  Pittsburgh    PA
# 117             3    2.5        8         1  Pittsburgh    PA
# 118            10    2.0        8         1  Pittsburgh    PA
# 119            51    3.0        8         1  Pittsburgh    PA
# 120            59    3.5        8         1  Pittsburgh    PA
# 121            28    4.5        8         1  Pittsburgh    PA
# 122             4    5.0        8         1  Pittsburgh    PA
# 123            19    4.0        8         1  Pittsburgh    PA
# 124            51    5.0        8         1  Pittsburgh    PA
# 125             3    5.0        8         1  Pittsburgh    PA
# 126            71    3.0        8         1  Pittsburgh    PA
# 127            14    2.5        8         1  Pittsburgh    PA
# 128             8    3.5        8         1  Pittsburgh    PA
# 129             4    5.0        8         1  Pittsburgh    PA
# 130            43    3.5        8         1  Pittsburgh    PA
# 131            73    4.0        8         1  Pittsburgh    PA
# 132             4    5.0        8         1  Pittsburgh    PA
# 133             5    2.0        8         1  Pittsburgh    PA
# 134            10    3.5        8         1  Pittsburgh    PA
# 135            32    4.5        8         1  Pittsburgh    PA
# 136             3    5.0        8         1  Pittsburgh    PA
# 137             4    5.0        8         1  Pittsburgh    PA
# 138            21    3.0        8         1  Pittsburgh    PA
# 139             6    5.0        8         1  Pittsburgh    PA
# 140             3    5.0        8         1  Pittsburgh    PA
# 141            21    3.0        8         1  Pittsburgh    PA
# 142             4    4.5        8         1  Pittsburgh    PA
# 143             4    4.0        8         1  Pittsburgh    PA
# 144            21    3.5        8         1  Pittsburgh    PA
# 145             6    2.0        8         1  Pittsburgh    PA
# 146             8    4.0        8         1  Pittsburgh    PA
# 147             3    2.5        8         1  Pittsburgh    PA
# 148             3    5.0        8         1  Pittsburgh    PA
# 149             6    1.5        8         1  Pittsburgh    PA

# %%
index=len(df)-1
last_busn=df[len(df)-1:]
last_busn['name']
# Out:
# 599    A Sunrise Towing
# Name: name, dtype: object

# %%
df[-1:]
# Out:
#                  name  category_0 category_1  take_out  review_count  stars  \
# 599  A Sunrise Towing  Automotive     Towing     False             4    1.0
#
#      city_id  state_id             city state
# 599       13         2  North Las Vegas    NV

# %%
df[-1:]['name']
# Out:
# 599    A Sunrise Towing
# Name: name, dtype: object

# %%
pitts=df['city']=='Pittsburgh'

# %%
type(pitts)
# Out:
# pandas.core.series.Series

# %%
pitts
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 595    False
# 596    False
# 597    False
# 598    False
# 599    False
# Name: city, Length: 600, dtype: bool

# %%
df[pitts]
# Out:
#                                                name            category_0  \
# 95                              Aamco Transmissions           Auto Repair
# 96   Animal Rescue League Shelter & Wildlife Center       Animal Shelters
# 97                           Aracri's Greentree Inn               Italian
# 98                            Atch-Mont Real Estate  Real Estate Services
# 99                               Atria's Restaurant        American (New)
# ..                                              ...                   ...
# 283                             Walter's Automotive           Auto Repair
# 284                     Washington's Landing Marina           Active Life
# 285                             West Liberty Cycles        Sporting Goods
# 286                                  Wiseguys Pizza           Restaurants
# 287                                     X Shadyside           Active Life
#
#               category_1  take_out  review_count  stars  city_id  state_id  \
# 95            Automotive     False            21    4.5        8         1
# 96         Veterinarians     False            43    4.0        8         1
# 97        American (New)      True            15    3.5        8         1
# 98   Property Management     False             3    2.0        8         1
# 99            Sandwiches      True            69    3.0        8         1
# ..                   ...       ...           ...    ...      ...       ...
# 283           Automotive     False            99    5.0        8         1
# 284              Boating     False             3    3.0        8         1
# 285                Bikes     False             8    4.5        8         1
# 286                Pizza      True            12    3.0        8         1
# 287                 Yoga     False            31    3.5        8         1
#
#            city state
# 95   Pittsburgh    PA
# 96   Pittsburgh    PA
# 97   Pittsburgh    PA
# 98   Pittsburgh    PA
# 99   Pittsburgh    PA
# ..          ...   ...
# 283  Pittsburgh    PA
# 284  Pittsburgh    PA
# 285  Pittsburgh    PA
# 286  Pittsburgh    PA
# 287  Pittsburgh    PA
#
# [193 rows x 10 columns]

# %%
rest = df['name'] == 'The Dragon Chinese Cuisine'

# %%
df[rest]['take_out']
# Out:
# 93    True
# Name: take_out, dtype: bool

# %%
cat0_bars=df['category_0']=='Bars'
cat1_bars=df['category_1']=='Bars'
df[cat0_bars | cat1_bars]
# Out:
#                                  name   category_0              category_1  \
# 12                      Emil's Lounge         Bars          American (New)
# 15              Alexion's Bar & Grill         Bars  American (Traditional)
# 32                     Rocky's Lounge         Bars  American (Traditional)
# 42             Duke's Upper Deck Cafe         Pubs                    Bars
# 62            Randy's Beer Barrel Pub         Pubs                    Bars
# 70                        TGI Fridays         Bars  American (Traditional)
# 77                         Applebee's         Bars  American (Traditional)
# 101  Bado's Pizza Grill and Ale House      Italian                    Bars
# 114                     Buffalo Blues  Restaurants                    Bars
# 119                      Cappy's Cafe         Bars  American (Traditional)
# 138                       Doc's Place         Bars                   Pizza
# 171                            Huddle         Bars  American (Traditional)
# 187                     Le Mardi Gras         Food                    Bars
# 203                       Mt Troy Inn         Bars               Nightlife
# 209              Nico's Recovery Room         Bars  American (Traditional)
# 232                    Primanti Bros.  Restaurants                    Bars
# 233                   Pub In the Park         Pubs                    Bars
# 272                    The Korner Pub         Pubs                    Bars
# 274                    The Park House         Pubs                    Bars
# 279                Tramp's Restaurant         Bars  American (Traditional)
# 288                         Bar Louie         Bars          American (New)
# 300                Buffalo Wild Wings         Bars  American (Traditional)
# 433                      Boomer's Bar         Bars  American (Traditional)
# 450                   Hard Hat Lounge    Dive Bars                    Bars
# 451                  Huntridge Tavern    Dive Bars                    Bars
# 452                        Jack's Pub         Pubs                    Bars
# 453                      Moon Doggies    Dive Bars                    Bars
# 515                        Jake's Bar         Bars               Nightlife
# 593            Sporting Chance Saloon         Bars               Nightlife
#
#      take_out  review_count  stars  city_id  state_id             city state
# 12       True            26    4.5        2         1         Braddock    PA
# 15       True            23    4.0        3         1         Carnegie    PA
# 32       True            10    4.0        3         1         Carnegie    PA
# 42       True            33    3.5        4         1        Homestead    PA
# 62      False             3    2.5        4         1        Homestead    PA
# 70       True            23    2.5        4         1        Homestead    PA
# 77       True             9    3.5        5         1    Mc Kees Rocks    PA
# 101      True            93    3.5        8         1       Pittsburgh    PA
# 114      True            62    3.0        8         1       Pittsburgh    PA
# 119      True            51    3.0        8         1       Pittsburgh    PA
# 138      True            21    3.0        8         1       Pittsburgh    PA
# 171      True            17    4.0        8         1       Pittsburgh    PA
# 187     False            48    4.0        8         1       Pittsburgh    PA
# 203     False             3    3.5        8         1       Pittsburgh    PA
# 209      True            24    3.5        8         1       Pittsburgh    PA
# 232      True           463    3.5        8         1       Pittsburgh    PA
# 233     False             6    4.5        8         1       Pittsburgh    PA
# 272     False             8    4.5        8         1       Pittsburgh    PA
# 274      True            61    4.0        8         1       Pittsburgh    PA
# 279      True             4    3.5        8         1       Pittsburgh    PA
# 288      True            92    2.5        9         1   West Homestead    PA
# 300      True           171    3.0       11         2        Henderson    NV
# 433     False            19    3.5       12         2        Las Vegas    NV
# 450     False            31    3.5       12         2        Las Vegas    NV
# 451     False            50    4.0       12         2        Las Vegas    NV
# 452     False            20    2.5       12         2        Las Vegas    NV
# 453     False            85    4.0       12         2        Las Vegas    NV
# 515     False            12    4.5       12         2        Las Vegas    NV
# 593     False             7    3.5       13         2  North Las Vegas    NV

# %%
cat0_bars=df['category_0']=='Bars'
cat1_bars=df['category_1']=='Bars'
carn=df['city']=='Carnegie'
df[(cat0_bars | cat1_bars) & carn]
# Out:
#                      name category_0              category_1  take_out  \
# 15  Alexion's Bar & Grill       Bars  American (Traditional)      True
# 32         Rocky's Lounge       Bars  American (Traditional)      True
#
#     review_count  stars  city_id  state_id      city state
# 15            23    4.0        3         1  Carnegie    PA
# 32            10    4.0        3         1  Carnegie    PA

# %%
cat_0 = df['category_0'].isin(["Bars", "Restaurants"])
cat_1 = df['category_1'].isin(["Bars", "Restaurants"])
carn=df["city"]=='Carnegie'
df[(cat_0 | cat_1) & carn]
# Out:
#                             name   category_0              category_1  \
# 15         Alexion's Bar & Grill         Bars  American (Traditional)
# 18  Barb's Country Junction Cafe  Restaurants                   Cafes
# 20    Don Don Chinese Restaurant  Restaurants                 Chinese
# 29                      Papa J's  Restaurants                 Italian
# 30    Porto Fino Pizzaria & Gyro  Restaurants                   Pizza
# 32                Rocky's Lounge         Bars  American (Traditional)
#
#     take_out  review_count  stars  city_id  state_id      city state
# 15      True            23    4.0        3         1  Carnegie    PA
# 18      True             9    4.0        3         1  Carnegie    PA
# 20      True            10    2.5        3         1  Carnegie    PA
# 29      True            81    3.5        3         1  Carnegie    PA
# 30     False             4    2.5        3         1  Carnegie    PA
# 32      True            10    4.0        3         1  Carnegie    PA

# %%
cat0_dbars=df['category_0']=='Dive Bars'
cat1_dbars=df['category_1']=='Dive Bars'
lv = df['city']=='Las Vegas'
dbars_lv=df[(cat0_dbars|cat1_dbars) & lv]
len(dbars_lv)
# Out:
# 3

# %%
stars=dbars_lv['stars']>=4.0
dbars_lv_4star=dbars_lv[stars]

# %%
dbars_lv_4star
# Out:
#                  name category_0 category_1  take_out  review_count  stars  \
# 451  Huntridge Tavern  Dive Bars       Bars     False            50    4.0
# 453      Moon Doggies  Dive Bars       Bars     False            85    4.0
#
#      city_id  state_id       city state
# 451       12         2  Las Vegas    NV
# 453       12         2  Las Vegas    NV

# %%
import random

# %%
rand_int=random.randint(0, len(dbars_lv_4star)-1)
rand_dbar=dbars_lv_4star[rand_int : rand_int + 1]
rand_dbar
# Out:
#              name category_0 category_1  take_out  review_count  stars  \
# 453  Moon Doggies  Dive Bars       Bars     False            85    4.0
#
#      city_id  state_id       city state
# 453       12         2  Las Vegas    NV

# %%
rand_int=random.randint(0, len(dbars_lv_4star)-1)
rand_dbar=dbars_lv_4star.iloc[rand_int]
rand_dbar
# Out:
# name            Moon Doggies
# category_0         Dive Bars
# category_1              Bars
# take_out               False
# review_count              85
# stars                      4
# city_id                   12
# state_id                   2
# city               Las Vegas
# state                     NV
# Name: 453, dtype: object

# %%
cat_0 = df["category_0"].str.contains("Nail Salon")
cat_1 = df["category_1"].str.contains("Nail Salon")
hend=df["city"]=="Henderson"
df[(cat_0|cat_1) & hend]
df[(cat_0|cat_1) & hend]["review_count"].sum()
# Out:
# 158

# %%
cat_0 = df["category_0"].str.contains("Auto Repair")
cat_1 = df["category_1"].str.contains("Auto Repair")
pitts=df["city"]=="Pittsburgh"
df[(cat_0|cat_1) & pitts]
df[(cat_0|cat_1) & pitts]["stars"].mean()
# Out:
# 4.5

# %%
df["city"].unique()
# Out:
# array(['Bellevue', 'Braddock', 'Carnegie', 'Homestead', 'Mc Kees Rocks',
#        'Mount Lebanon', 'Munhall', 'Pittsburgh', 'West Homestead',
#        'West Mifflin', 'Henderson', 'Las Vegas', 'North Las Vegas'],
#       dtype=object)

# %%
df["city"].value_counts()
# Out:
# Pittsburgh         193
# Las Vegas          133
# Henderson          130
# Homestead           41
# North Las Vegas     37
# Carnegie            22
# Bellevue            12
# Mc Kees Rocks       10
# West Mifflin         9
# Mount Lebanon        4
# Munhall              4
# West Homestead       3
# Braddock             2
# Name: city, dtype: int64

# %%
df["city"].nunique()
# Out:
# 13

# %%
df["categories"]=df["category_0"].str.cat(df["category_1"], sep=',')

# %%
df[df["categories"].str.contains("Pizza")]
# Out:
#                                    name              category_0   category_1  \
# 6                      Luigi's Pizzeria             Restaurants        Pizza
# 8                   R & B's Pizza Place             Restaurants        Pizza
# 30           Porto Fino Pizzaria & Gyro             Restaurants        Pizza
# 48                Homestead Capri Pizza                 Italian        Pizza
# 49                Italian Village Pizza             Restaurants        Pizza
# 73                 Uno Pizzeria & Grill  American (Traditional)        Pizza
# 83            Pasquarelli's Pizza House             Restaurants        Pizza
# 94                    The Pizza Company             Restaurants        Pizza
# 103           Bellisario's Pizza Palace                 Italian        Pizza
# 105                        Beto's Pizza             Restaurants        Pizza
# 117       Calabria's Italian Restaurant             Restaurants        Pizza
# 127  Chubby's Pizza & Hoagies Northside             Restaurants        Pizza
# 138                         Doc's Place                    Bars        Pizza
# 146                  Eddie's Pizza Haus                 Italian        Pizza
# 153                    Fiori's Pizzaria                 Italian        Pizza
# 172                        Il Pizzaiolo                 Italian        Pizza
# 188               Little Nipper's Pizza             Restaurants        Pizza
# 197     Minutello's Restaurant & Lounge                 Italian        Pizza
# 229                           Pizza Hut                 Italian        Pizza
# 286                      Wiseguys Pizza             Restaurants        Pizza
# 291               Bellisario Pizza Shop             Restaurants        Pizza
# 296                        Latina Pizza             Restaurants        Pizza
# 359   Sammy's Woodfired Pizza and Grill                   Pizza  Gluten-Free
# 395               Buon Gusto Ristorante             Restaurants        Pizza
# 396                           Carmine's                 Italian        Pizza
# 408                   Papa John's Pizza             Restaurants        Pizza
# 409                           Pizza Hut             Restaurants        Pizza
# 536                Little Caesars Pizza             Restaurants        Pizza
# 594                      Domino's Pizza              Sandwiches        Pizza
#
#      take_out  review_count  stars  city_id  state_id             city state  \
# 6        True            18    4.0        1         1         Bellevue    PA
# 8        True            17    4.0        1         1         Bellevue    PA
# 30      False             4    2.5        3         1         Carnegie    PA
# 48       True             4    2.0        4         1        Homestead    PA
# 49      False             6    2.5        4         1        Homestead    PA
# 73       True            55    3.0        4         1        Homestead    PA
# 83       True            13    4.0        5         1    Mc Kees Rocks    PA
# 94       True            12    4.0        7         1          Munhall    PA
# 103      True            21    3.5        8         1       Pittsburgh    PA
# 105      True           145    4.0        8         1       Pittsburgh    PA
# 117     False             3    2.5        8         1       Pittsburgh    PA
# 127      True            14    2.5        8         1       Pittsburgh    PA
# 138      True            21    3.0        8         1       Pittsburgh    PA
# 146      True             8    4.0        8         1       Pittsburgh    PA
# 153      True           189    4.5        8         1       Pittsburgh    PA
# 172      True           194    4.0        8         1       Pittsburgh    PA
# 188      True            10    2.5        8         1       Pittsburgh    PA
# 197      True             8    3.0        8         1       Pittsburgh    PA
# 229      True             6    1.5        8         1       Pittsburgh    PA
# 286      True            12    3.0        8         1       Pittsburgh    PA
# 291      True             6    3.5       10         1     West Mifflin    PA
# 296      True             6    4.5       10         1     West Mifflin    PA
# 359      True            59    3.5       11         2        Henderson    NV
# 395      True           279    4.0       11         2        Henderson    NV
# 396      True            54    3.0       11         2        Henderson    NV
# 408      True            11    2.0       11         2        Henderson    NV
# 409      True            14    3.0       11         2        Henderson    NV
# 536      True             4    4.0       12         2        Las Vegas    NV
# 594      True             6    4.5       13         2  North Las Vegas    NV
#
#                        categories
# 6               Restaurants,Pizza
# 8               Restaurants,Pizza
# 30              Restaurants,Pizza
# 48                  Italian,Pizza
# 49              Restaurants,Pizza
# 73   American (Traditional),Pizza
# 83              Restaurants,Pizza
# 94              Restaurants,Pizza
# 103                 Italian,Pizza
# 105             Restaurants,Pizza
# 117             Restaurants,Pizza
# 127             Restaurants,Pizza
# 138                    Bars,Pizza
# 146                 Italian,Pizza
# 153                 Italian,Pizza
# 172                 Italian,Pizza
# 188             Restaurants,Pizza
# 197                 Italian,Pizza
# 229                 Italian,Pizza
# 286             Restaurants,Pizza
# 291             Restaurants,Pizza
# 296             Restaurants,Pizza
# 359             Pizza,Gluten-Free
# 395             Restaurants,Pizza
# 396                 Italian,Pizza
# 408             Restaurants,Pizza
# 409             Restaurants,Pizza
# 536             Restaurants,Pizza
# 594              Sandwiches,Pizza

# %%
df["rating"]= df["stars"]*2

# %%
df.head()
# Out:
#                            name   category_0       category_1  take_out  \
# 0  China Sea Chinese Restaurant  Restaurants          Chinese      True
# 1          Discount Tire Center        Tires       Automotive     False
# 2                  Frankfurters  Restaurants         Hot Dogs      True
# 3             Fred Dietz Floral     Shopping  Flowers & Gifts     False
# 4                 Kuhn's Market         Food          Grocery     False
#
#    review_count  stars  city_id  state_id      city state  \
# 0            11    2.5        1         1  Bellevue    PA
# 1            24    4.5        1         1  Bellevue    PA
# 2             3    4.5        1         1  Bellevue    PA
# 3             6    4.0        1         1  Bellevue    PA
# 4             8    3.5        1         1  Bellevue    PA
#
#                  categories  rating
# 0       Restaurants,Chinese     5.0
# 1          Tires,Automotive     9.0
# 2      Restaurants,Hot Dogs     9.0
# 3  Shopping,Flowers & Gifts     8.0
# 4              Food,Grocery     7.0

# %%
def convert_to_rating(x):
    return (str(x)+" out of 10")

# %%
df["rating"]=df["rating"].apply(convert_to_rating)

# %%
df.head()
# Out:
#                            name   category_0       category_1  take_out  \
# 0  China Sea Chinese Restaurant  Restaurants          Chinese      True
# 1          Discount Tire Center        Tires       Automotive     False
# 2                  Frankfurters  Restaurants         Hot Dogs      True
# 3             Fred Dietz Floral     Shopping  Flowers & Gifts     False
# 4                 Kuhn's Market         Food          Grocery     False
#
#    review_count  stars  city_id  state_id      city state  \
# 0            11    2.5        1         1  Bellevue    PA
# 1            24    4.5        1         1  Bellevue    PA
# 2             3    4.5        1         1  Bellevue    PA
# 3             6    4.0        1         1  Bellevue    PA
# 4             8    3.5        1         1  Bellevue    PA
#
#                  categories         rating
# 0       Restaurants,Chinese  5.0 out of 10
# 1          Tires,Automotive  9.0 out of 10
# 2      Restaurants,Hot Dogs  9.0 out of 10
# 3  Shopping,Flowers & Gifts  8.0 out of 10
# 4              Food,Grocery  7.0 out of 10

# %%
bars_rest=df["category_0"].isin(['Bars', 'Restaurants'])
df_bars_rest=df[bars_rest]
df_bars_rest
# Out:
#                              name   category_0              category_1  \
# 0    China Sea Chinese Restaurant  Restaurants                 Chinese
# 2                    Frankfurters  Restaurants                Hot Dogs
# 6                Luigi's Pizzeria  Restaurants                   Pizza
# 8             R & B's Pizza Place  Restaurants                   Pizza
# 9                      Rusty Nail  Restaurants  American (Traditional)
# ..                            ...          ...                     ...
# 537                      Pho So 1  Restaurants              Vietnamese
# 538                    Rice To-Go  Restaurants                 Chinese
# 539               Wienerschnitzel  Restaurants               Fast Food
# 593        Sporting Chance Saloon         Bars               Nightlife
# 597               Jack In the Box  Restaurants               Fast Food
#
#      take_out  review_count  stars  city_id  state_id             city state  \
# 0        True            11    2.5        1         1         Bellevue    PA
# 2        True             3    4.5        1         1         Bellevue    PA
# 6        True            18    4.0        1         1         Bellevue    PA
# 8        True            17    4.0        1         1         Bellevue    PA
# 9        True            32    3.5        1         1         Bellevue    PA
# ..        ...           ...    ...      ...       ...              ...   ...
# 537      True           763    3.5       12         2        Las Vegas    NV
# 538      True            19    3.0       12         2        Las Vegas    NV
# 539     False             3    1.0       12         2        Las Vegas    NV
# 593     False             7    3.5       13         2  North Las Vegas    NV
# 597      True            12    3.0       13         2  North Las Vegas    NV
#
#                              categories         rating
# 0                   Restaurants,Chinese  5.0 out of 10
# 2                  Restaurants,Hot Dogs  9.0 out of 10
# 6                     Restaurants,Pizza  8.0 out of 10
# 8                     Restaurants,Pizza  8.0 out of 10
# 9    Restaurants,American (Traditional)  7.0 out of 10
# ..                                  ...            ...
# 537              Restaurants,Vietnamese  7.0 out of 10
# 538                 Restaurants,Chinese  6.0 out of 10
# 539               Restaurants,Fast Food  2.0 out of 10
# 593                      Bars,Nightlife  7.0 out of 10
# 597               Restaurants,Fast Food  6.0 out of 10
#
# [87 rows x 12 columns]

# %%
pivot_state_cat=pd.pivot_table(df_bars_rest, index=["state", "city", "category_0"])

# %%
pivot_state_cat[["review_count", "stars"]]
# Out:
#                                    review_count     stars
# state city            category_0
# NV    Henderson       Bars           171.000000  3.000000
#                       Restaurants    102.454545  3.181818
#       Las Vegas       Bars            15.500000  4.000000
#                       Restaurants    221.153846  3.153846
#       North Las Vegas Bars             7.000000  3.500000
#                       Restaurants     12.000000  3.000000
# PA    Bellevue        Restaurants     14.000000  3.916667
#       Braddock        Bars            26.000000  4.500000
#       Carnegie        Bars            16.500000  4.000000
#                       Restaurants     26.000000  3.125000
#       Homestead       Bars            23.000000  2.500000
#                       Restaurants      6.000000  2.500000
#       Mc Kees Rocks   Bars             9.000000  3.500000
#                       Restaurants      7.333333  3.333333
#       Munhall         Restaurants      9.500000  3.500000
#       Pittsburgh      Bars            20.000000  3.416667
#                       Restaurants     67.000000  3.203704
#       West Homestead  Bars            92.000000  2.500000
#       West Mifflin    Restaurants      5.000000  4.333333

# %%
import numpy as np
pivot_agg=pd.pivot_table(
    df, index=["state", "city"],
    values=["review_count"],
    aggfunc=[np.sum]
)
pivot_agg
# Out:
#                                sum
#                       review_count
# state city
# NV    Henderson               4332
#       Las Vegas               7226
#       North Las Vegas          398
# PA    Bellevue                 158
#       Braddock                  29
#       Carnegie                 299
#       Homestead                953
#       Mc Kees Rocks            107
#       Mount Lebanon             25
#       Munhall                   91
#       Pittsburgh              6470
#       West Homestead           124
#       West Mifflin              51

# %%
pivot_a2=pd.pivot_table(
    df, index=["state", "city"],
    values=["review_count"],
    columns=["take_out"],
    aggfunc=[np.sum]
)
pivot_a2
# Out:
#                                sum
#                       review_count
# take_out                     False True
# state city
# NV    Henderson               2009  2323
#       Las Vegas               1619  5607
#       North Las Vegas          293   105
# PA    Bellevue                  52   106
#       Braddock                   3    26
#       Carnegie                  74   225
#       Homestead                323   630
#       Mc Kees Rocks             48    59
#       Mount Lebanon             13    12
#       Munhall                   12    79
#       Pittsburgh              1447  5023
#       West Homestead             7   117
#       West Mifflin              36    15

# %%
pivot_a3=pd.pivot_table(
    df, index=["state", "city"],
    columns=["take_out"],
    aggfunc={"review_count":np.sum, "stars":np.mean}
)
pivot_a3
# Out:
#                       review_count           stars
# take_out                     False True      False     True
# state city
# NV    Henderson               2009  2323  3.469697  3.258065
#       Las Vegas               1619  5607  3.423077  3.310345
#       North Las Vegas          293   105  3.155172  2.562500
# PA    Bellevue                  52   106  3.750000  3.750000
#       Braddock                   3    26  5.000000  4.500000
#       Carnegie                  74   225  3.269231  3.722222
#       Homestead                323   630  3.416667  2.909091
#       Mc Kees Rocks             48    59  3.666667  3.714286
#       Mount Lebanon             13    12  3.000000  3.500000
#       Munhall                   12    79  3.000000  3.000000
#       Pittsburgh              1447  5023  3.836364  3.566265
#       West Homestead             7   117  4.500000  2.750000
#       West Mifflin              36    15  3.500000  4.333333

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import matplotlib.pyplot as plt

# %%
df_pitt=df[df["city"]=="Pittsburgh"]

# %%
df_pitt.head()
# Out:
#                                               name            category_0  \
# 95                             Aamco Transmissions           Auto Repair
# 96  Animal Rescue League Shelter & Wildlife Center       Animal Shelters
# 97                          Aracri's Greentree Inn               Italian
# 98                           Atch-Mont Real Estate  Real Estate Services
# 99                              Atria's Restaurant        American (New)
#
#              category_1  take_out  review_count  stars  city_id  state_id  \
# 95           Automotive     False            21    4.5        8         1
# 96        Veterinarians     False            43    4.0        8         1
# 97       American (New)      True            15    3.5        8         1
# 98  Property Management     False             3    2.0        8         1
# 99           Sandwiches      True            69    3.0        8         1
#
#           city state                                categories         rating
# 95  Pittsburgh    PA                    Auto Repair,Automotive  9.0 out of 10
# 96  Pittsburgh    PA             Animal Shelters,Veterinarians  8.0 out of 10
# 97  Pittsburgh    PA                    Italian,American (New)  7.0 out of 10
# 98  Pittsburgh    PA  Real Estate Services,Property Management  4.0 out of 10
# 99  Pittsburgh    PA                 American (New),Sandwiches  6.0 out of 10

# %%
df_vegas=df[df["city"]=="Las Vegas"]

# %%
df_vegas.head()
# Out:
#                               name          category_0  \
# 430          Reliable Tax Services  Financial Services
# 431  Paradise Electro Stimulations            Shopping
# 432                     The Studio            Shopping
# 433                   Boomer's Bar                Bars
# 434                   Omelet House  Breakfast & Brunch
#
#                  category_1  take_out  review_count  stars  city_id  state_id  \
# 430             Accountants     False             3    4.5       12         2
# 431                   Adult     False             4    4.5       12         2
# 432                   Adult     False             7    5.0       12         2
# 433  American (Traditional)     False            19    3.5       12         2
# 434  American (Traditional)      True           703    4.5       12         2
#
#           city state                                 categories  \
# 430  Las Vegas    NV             Financial Services,Accountants
# 431  Las Vegas    NV                             Shopping,Adult
# 432  Las Vegas    NV                             Shopping,Adult
# 433  Las Vegas    NV                Bars,American (Traditional)
# 434  Las Vegas    NV  Breakfast & Brunch,American (Traditional)
#
#              rating
# 430   9.0 out of 10
# 431   9.0 out of 10
# 432  10.0 out of 10
# 433   7.0 out of 10
# 434   9.0 out of 10

# %%
pitt_stars=df_pitt["stars"]
vegas_stars=df_vegas["stars"]

# %%
plt.hist(
    pitt_stars,
    alpha=0.3,
    color='yellow',
    label='Pittsburgh',
    bins='auto'
)

plt.hist(
    vegas_stars,
    alpha=0.3,
    color='red',
    label='Las Vegas',
    bins='auto'
)

plt.xlabel("Rating")
plt.ylabel("Number of Rating Scores")

plt.legend(loc='best')

plt.title("Review distribution of Pittsburgh and Las Vegas")

plt.show()

# %%
plt.hist(
    [pitt_stars, vegas_stars],
    alpha=0.7,
    color=['red', 'blue'],
    label=['Pittsburgh', 'Las Vegas'],
    bins='auto'
)

plt.xlabel('Rating')
plt.ylabel("Number of Rating Scores")

plt.legend(loc="best")

plt.title("Review Distribution of Pittsburgh and Las Vegas")

plt.show()

# %%
df_health=df[df["category_0"]=="Health & Medical"]
df_fast=df[df["category_0"]=="Fast Food"]
df_brunch=df[df["category_0"]=="Breakfast & Brunch"]
df_brunch.head()
# Out:
#                              name          category_0              category_1  \
# 24                      Gab & Eat  Breakfast & Brunch              Sandwiches
# 131            Crepes Parisiennes  Breakfast & Brunch               Creperies
# 240                 Ritters Diner  Breakfast & Brunch  American (Traditional)
# 266  The Bloomfield Sandwich Shop  Breakfast & Brunch              Sandwiches
# 268       The Dor-Stop Restaurant  Breakfast & Brunch                  Diners
#
#      take_out  review_count  stars  city_id  state_id        city state  \
# 24       True            69    4.5        3         1    Carnegie    PA
# 131      True            73    4.0        8         1  Pittsburgh    PA
# 240      True           146    3.5        8         1  Pittsburgh    PA
# 266      True            41    4.0        8         1  Pittsburgh    PA
# 268      True           275    4.5        8         1  Pittsburgh    PA
#
#                                     categories         rating
# 24               Breakfast & Brunch,Sandwiches  9.0 out of 10
# 131               Breakfast & Brunch,Creperies  8.0 out of 10
# 240  Breakfast & Brunch,American (Traditional)  7.0 out of 10
# 266              Breakfast & Brunch,Sandwiches  8.0 out of 10
# 268                  Breakfast & Brunch,Diners  9.0 out of 10

# %%
plt.scatter(
    df_health["stars"], df_health["review_count"],
    marker="o",
    color='r',
    alpha=0.7,
    s=124,
    label=["Health & Medical"]
)

plt.scatter(
    df_fast["stars"], df_fast["review_count"],
    marker="h",
    color='b',
    alpha=0.7,
    s=124,
    label=["Fast Food"]
)

plt.scatter(
    df_brunch["stars"], df_brunch["review_count"],
    marker="^",
    color='g',
    alpha=0.7,
    s=124,
    label=["Breakfast & Brunch"]
)

plt.xlabel=('Rating')
plt.ylabel('Review Count')

plt.legend(loc="upper left")

axes=plt.gca()
axes.set_yscale('log')

plt.show()
